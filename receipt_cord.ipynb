# %% [markdown]
# # Receipt Cord Data
#
# Link: <https://huggingface.co/datasets/naver-clova-ix/cord-v2>

# %% [markdown]
# # Data preprocessing

# %%
import pandas as pd
import os

# %%
df_list = []
for filepath in os.listdir('receipt_cord/'):
    df = pd.read_parquet(os.path.join('receipt_cord', filepath))
    df.drop(columns=['image'], inplace=True)
    df['split'] = 'train' if 'train' in filepath else 'test' if 'test' in filepath else 'val'
    df_list.append(df)

# %%
df = pd.concat(df_list, ignore_index=True)
df.shape
# Out:
# (1000, 2)

# %%
# parse nested json to get product name
import ast

def get_prod_names(nested_json):
    try:
        nested_json = ast.literal_eval(nested_json)
    except:
        return None
    
    if 'gt_parse' in nested_json:
        if 'menu' in nested_json['gt_parse']:
            if isinstance(nested_json['gt_parse']['menu'], list):
                try:
                    product_names = list(map(lambda x: x['nm'], nested_json['gt_parse']['menu']))
                    return product_names
                except:
                    return None
            else:
                try:
                    return [nested_json['gt_parse']['menu']['nm']]
                except:
                    return None
    else:
        return None

# %%
df['product_name'] = df['ground_truth'].apply(get_prod_names)

# %%
df.dropna(inplace=True)

# %%
df = df.explode('product_name').reset_index(drop=True)

# %%
df.drop(columns=['ground_truth'], inplace=True)

# %%
df['type'] = df['product_name'].apply(lambda x: isinstance(x, list))

# %%
df = df[df.type==False]

# %%
df
# Out:
#      split         product_name   type
# 0     test           -TICKET CP  False
# 1     test          J.STB PROMO  False
# 2     test              Y.B.BAT  False
# 3     test          Y.BASO PROM  False
# 4     test     JASMINE MT ( L )  False
# ...    ...                  ...    ...
# 2563   val           PAHA BAWAH  False
# 2564   val         Choco Cheese  False
# 2565   val        Lemon Tea (L)  False
# 2566   val  Hulk Topper Package  False
# 2567   val          Giant Squid  False
#
# [2564 rows x 3 columns]

# %% [markdown]
# ## For labelling

# %%
# text_file = open("for_labelling_2.txt", "w")
# product_list = df.product_name.unique().tolist()[1004:]
# product_list = list(set(product_list))
# print(len(product_list))
# n = text_file.write('\n'.join(product_list))
# text_file.close()
# Out:
# 716

# %%
# stopped at 1004 row

# %%
# stopped at 1004 + 224

# %%
len(df.product_name.tolist()), len(df.product_name.unique().tolist())
# Out:
# (2564, 1720)

# %% [markdown]
# ## Using labelled annotations

# %%
import pandas as pd
import json

# %%
with open('annotations.json') as json_file:
    data = json.load(json_file)

# %%
with open('annotations_2.json') as json_file:
    add_data = json.load(json_file)

# %%
annotations = data['annotations']

# %%
annotations += add_data['annotations']

# %%
annotations = [i for i in annotations if i is not None]

# %%
text = list(map(lambda x: x[0].replace('\r', ''), annotations))
entities = list(map(lambda x: x[1]['entities'], annotations))

# %%
df = pd.DataFrame({'text': text, 'entities': entities})
df
# Out:
#                       text                        entities
# 0              J.STB PROMO    [[0, 5, PROD], [6, 11, ADJ]]
# 1                  Y.B.BAT                  [[0, 7, PROD]]
# 2              Y.BASO PROM    [[0, 6, PROD], [7, 11, ADJ]]
# 3         JASMINE MT ( L )  [[0, 10, PROD], [11, 16, ADJ]]
# 4               DONAT GULA    [[0, 5, PROD], [6, 10, ADJ]]
# ...                    ...                             ...
# 1053          DADAR PISANG                 [[0, 12, PROD]]
# 1054  JAPANEESE GR TEA HOT  [[0, 16, PROD], [17, 20, ADJ]]
# 1055         <FC Winger HC                 [[4, 10, PROD]]
# 1056          SUPER CHEESE                 [[0, 12, PROD]]
# 1057           CHUM CHURUM                 [[0, 11, PROD]]
#
# [1058 rows x 2 columns]

# %%
df = df.groupby('text')['entities'].first().reset_index()

# %%
def split_text_to_tags(row):
    text = row['text']
    entities = row['entities']
    
    all_tags = []
    left = 0
    while len(entities) > 0:
        if left!=entities[0][0]:
            all_tags.append([left, entities[0][0], 'O'])
        all_tags.append(entities[0])
        left = entities[0][1]
        entities = entities[1:]
    if left!=len(text):
        all_tags.append([left, len(text), 'O'])
    return all_tags

# %%
df['tags'] = df.apply(split_text_to_tags, axis=1)

# %%
df = df.explode('tags').reset_index().rename(columns={'index': 'text_index'})
df.dropna(inplace=True)
df['entity'] = df.apply(lambda row: row['text'][row['tags'][0]: row['tags'][1]], axis=1)
df = df[df.entity!=' '].reset_index(drop=True)

# %%
df['label'] = df['tags'].apply(lambda x: x[2])

# %%
import re
df['entity'] = df['entity'].apply(lambda x: re.split(r"([^a-zA-Z0-9])", x))

# %%
df = df.explode('entity').reset_index()
df = df[~df.entity.isin(['', ' '])].reset_index(drop=True)

# %%
df['pos'] = df.groupby(['index']).cumcount()+1

# %%
df['pos'] = df.apply(lambda row: '' if row['label']=='O' else 'B-' if row['pos']==1 else 'I-', axis=1)

# %%
df['pos_tag'] = df['pos'] + df['label']

# %%
df = df[['text_index', 'text', 'entity', 'pos_tag']]

# %%
data = df.groupby('text_index')['pos_tag'].apply(list).reset_index()

# %%
new_df = df.groupby('text_index')['text'].first().reset_index()

# %%
data = pd.merge(data, new_df, on='text_index')

# %%
data
# Out:
#      text_index                            pos_tag                        text
# 0             0          [O, O, B-PROD, B-PROD, O]        #F11 CREAM HAMBURG 0
# 1             1                        [O, B-PROD]            #PKTPOLSBTSPON2S
# 2             2  [O, O, O, B-PROD, I-PROD, I-PROD]   (TA) BIHUN GORENG SEAFOOD
# 3             3  [O, O, O, B-PROD, I-PROD, I-PROD]  (TA) KWETIAW SEAFOOD SIRAM
# 4             4          [O, O, O, B-PROD, I-PROD]            (TA) NASI GORENG
# ..          ...                                ...                         ...
# 933         933                    [B-ADJ, B-PROD]                   green tea
# 934         934                   [B-PROD, I-PROD]                   phad thai
# 935         935            [B-ADJ, B-PROD, I-PROD]              red curry beef
# 936         936                   [B-PROD, I-PROD]                steamed rice
# 937         937          [B-PROD, I-PROD, O, O, O]              sun kissed (P)
#
# [938 rows x 3 columns]

# %%
# data.to_csv('labelled_data_new.csv', index=False)

# %% [markdown]
# ## Split data and Define Unique Labels

# %%
data = pd.read_csv('labelled_data_new.csv')

# %%
import ast

# %%
data['pos_tag'] = data['pos_tag'].apply(ast.literal_eval)

# %%
data
# Out:
#      text_index                            pos_tag                        text
# 0             0          [O, O, B-PROD, B-PROD, O]        #F11 CREAM HAMBURG 0
# 1             1                        [O, B-PROD]            #PKTPOLSBTSPON2S
# 2             2  [O, O, O, B-PROD, I-PROD, I-PROD]   (TA) BIHUN GORENG SEAFOOD
# 3             3  [O, O, O, B-PROD, I-PROD, I-PROD]  (TA) KWETIAW SEAFOOD SIRAM
# 4             4          [O, O, O, B-PROD, I-PROD]            (TA) NASI GORENG
# ..          ...                                ...                         ...
# 933         933                    [B-ADJ, B-PROD]                   green tea
# 934         934                   [B-PROD, I-PROD]                   phad thai
# 935         935            [B-ADJ, B-PROD, I-PROD]              red curry beef
# 936         936                   [B-PROD, I-PROD]                steamed rice
# 937         937          [B-PROD, I-PROD, O, O, O]              sun kissed (P)
#
# [938 rows x 3 columns]

# %%
data.rename(columns={'pos_tag': 'labels'}, inplace=True)

# %%
labels = data['pos_tag'].tolist()
unique_labels = set()

for lb in labels:
    [unique_labels.add(i) for i in lb if i not in unique_labels]
    
labels_to_ids = {k: v for v, k in enumerate(unique_labels)}
ids_to_labels = {v: k for v, k in enumerate(unique_labels)}

# %% [markdown]
# # BERT pretrained

# %%
import pandas as pd
import torch 
import numpy as np
from transformers import BertTokenizerFast, BertForTokenClassification, BertModel
from torch.utils.data import DataLoader
from tqdm import tqdm
from torch.optim import SGD

tokenizer = BertTokenizerFast.from_pretrained('bert-base-uncased')

# %% [markdown]
# ## Build Model

# %%
class MyBertModel(torch.nn.Module):

    def __init__(self):

        super(MyBertModel, self).__init__()

        self.bert = BertForTokenClassification.from_pretrained('bert-base-uncased', num_labels=len(unique_labels))

    def forward(self, input_id, mask, label):

        output = self.bert(input_ids=input_id, attention_mask=mask, labels=label, return_dict=False)

        return output

# %% [markdown]
# ## Model

# %%
model = MyBertModel()
model.load_state_dict(torch.load('bert-base-uncased.pt'))
model.eval()
# Out:
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertForTokenClassification: ['cls.predictions.bias', 'cls.predictions.transform.LayerNorm.bias', 'cls.seq_relationship.bias', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.dense.weight', 'cls.seq_relationship.weight', 'cls.predictions.decoder.weight', 'cls.predictions.transform.LayerNorm.weight']
# - This IS expected if you are initializing BertForTokenClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForTokenClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForTokenClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# MyBertModel(
#   (bert): BertForTokenClassification(
#     (bert): BertModel(
#       (embeddings): BertEmbeddings(
#         (word_embeddings): Embedding(30522, 768, padding_idx=0)
#         (position_embeddings): Embedding(512, 768)
#         (token_type_embeddings): Embedding(2, 768)
#         (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#       (encoder): BertEncoder(
#         (layer): ModuleList(
#           (0-11): 12 x BertLayer(
#             (attention): BertAttention(
#               (self): BertSelfAttention(
#                 (query): Linear(in_features=768, out_features=768, bias=True)
#                 (key): Linear(in_features=768, out_features=768, bias=True)
#                 (value): Linear(in_features=768, out_features=768, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=768, out_features=768, bias=True)
#                 (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): BertIntermediate(
#               (dense): Linear(in_features=768, out_features=3072, bias=True)
#               (intermediate_act_fn): GELUActivation()
#             )
#             (output): BertOutput(
#               (dense): Linear(in_features=3072, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#         )
#       )
#     )
#     (dropout): Dropout(p=0.1, inplace=False)
#     (classifier): Linear(in_features=768, out_features=9, bias=True)
#   )
# )

# %%
from seqeval.metrics import f1_score

def evaluate(model, df_test):
    test_dataset = DataSequence(df_test)

    test_dataloader = DataLoader(test_dataset, num_workers=4, batch_size=1)

    use_cuda = torch.cuda.is_available()
    device = torch.device("cuda" if use_cuda else "cpu")

    if use_cuda:
        model = model.cuda()

    total_acc_test = 0.0
    total_f1_test = 0

    for test_data, test_label in test_dataloader:

            test_label = test_label.to(device)
            mask = test_data['attention_mask'].squeeze(1).to(device)

            input_id = test_data['input_ids'].squeeze(1).to(device)

            loss, logits = model(input_id, mask, test_label)

            for i in range(logits.shape[0]):

                logits_clean = logits[i][test_label[i] != -100]
                label_clean = test_label[i][test_label[i] != -100]

                predictions = logits_clean.argmax(dim=1)
                acc = (predictions == label_clean).float().mean()
                total_acc_test += acc

                pred_labels = [[ids_to_labels[i] for i in label_clean.tolist()]]
                val_labels = [[ids_to_labels[i] for i in predictions.tolist()]]
                f1 = f1_score(val_labels, pred_labels)
                total_f1_test += f1

    print(f'Test Accuracy: {total_acc_test / len(df_test): .3f} | Test F1 Score: {total_f1_test / len(df_test): .3f}')

# %%
def align_word_ids(texts):
  
    tokenized_inputs = tokenizer(texts, padding='max_length', max_length=512, truncation=True)

    word_ids = tokenized_inputs.word_ids()

    previous_word_idx = None
    label_ids = []

    for word_idx in word_ids:

        if word_idx is None:
            label_ids.append(-100)

        elif word_idx != previous_word_idx:
            try:
                label_ids.append(1)
            except:
                label_ids.append(-100)
        else:
            try:
                label_ids.append(1 if label_all_tokens else -100)
            except:
                label_ids.append(-100)
        previous_word_idx = word_idx

    return label_ids


def evaluate_one_text(model, sentence):
    use_cuda = torch.cuda.is_available()
    device = torch.device("cuda" if use_cuda else "cpu")

    if use_cuda:
        model = model.cuda()

    text = tokenizer(sentence, padding='max_length', max_length = 512, truncation=True, return_tensors="pt")

    mask = text['attention_mask'].to(device)
    input_id = text['input_ids'].to(device)
    label_ids = torch.Tensor(align_word_ids(sentence)).unsqueeze(0).to(device)

    logits = model(input_id, mask, None)
    logits_clean = logits[0][label_ids != -100]

    predictions = logits_clean.argmax(dim=1).tolist()
    prediction_label = [ids_to_labels[i] for i in predictions]
    print(sentence)
    print(prediction_label)

# %%
evaluate_one_text(model, '(TA) BIHUN GORENG SEAFOOD')
# Out:
# (TA) BIHUN GORENG SEAFOOD
# ['O', 'O', 'O', 'B-BRAND', 'B-PROD', 'B-PROD']

# %% [markdown]
# # Embeddings
#
# Using the predicted tags, remove all but product tags

# %%
import re
data['text_tokenized'] = data['text'].apply(lambda x: re.split(r"([^a-zA-Z0-9])", x))
data['text_tokenized'] = data['text_tokenized'].apply(lambda x: [i for i in x if i not in ['',' ']])

# %%
data['match'] = data.apply(lambda row: len(row['labels']) == len(row['text_tokenized']), axis=1)

# %%
data = data[data.match==True].reset_index(drop=True)

# %%
data
# Out:
#      text_index                             labels
# 0             0          [O, O, B-PROD, B-PROD, O]  \
# 1             1                        [O, B-PROD]
# 2             2  [O, O, O, B-PROD, I-PROD, I-PROD]
# 3             3  [O, O, O, B-PROD, I-PROD, I-PROD]
# 4             4          [O, O, O, B-PROD, I-PROD]
# ..          ...                                ...
# 928         933                    [B-ADJ, B-PROD]
# 929         934                   [B-PROD, I-PROD]
# 930         935            [B-ADJ, B-PROD, I-PROD]
# 931         936                   [B-PROD, I-PROD]
# 932         937          [B-PROD, I-PROD, O, O, O]
#
#                            text                       text_tokenized  match
# 0          #F11 CREAM HAMBURG 0          [#, F11, CREAM, HAMBURG, 0]   True
# 1              #PKTPOLSBTSPON2S                 [#, PKTPOLSBTSPON2S]   True
# 2     (TA) BIHUN GORENG SEAFOOD   [(, TA, ), BIHUN, GORENG, SEAFOOD]   True
# 3    (TA) KWETIAW SEAFOOD SIRAM  [(, TA, ), KWETIAW, SEAFOOD, SIRAM]   True
# 4              (TA) NASI GORENG             [(, TA, ), NASI, GORENG]   True
# ..                          ...                                  ...    ...
# 928                   green tea                         [green, tea]   True
# 929                   phad thai                         [phad, thai]   True
# 930              red curry beef                   [red, curry, beef]   True
# 931                steamed rice                      [steamed, rice]   True
# 932              sun kissed (P)               [sun, kissed, (, P, )]   True
#
# [933 rows x 5 columns]

# %%
def get_prod_names(row):
    keep = []
    for i in range(len(row['labels'])):
        if 'PROD' in row['labels'][i]:
            keep.append(row['text_tokenized'][i])
    return keep

# %%
def get_adj(row):
    keep = []
    for i in range(len(row['labels'])):
        if 'ADJ' in row['labels'][i]:
            keep.append(row['text_tokenized'][i])
    return keep

# %%
data['adj_tags'] = data.apply(get_adj, axis=1)
data['product_tags'] = data.apply(get_prod_names, axis=1)

# %%
data['product_name'] = data['product_tags'].apply(lambda x: ' '.join(x))
data['adj'] = data['adj_tags'].apply(lambda x: ' '.join(x))

# %%
data[data.product_name=='']
# Out:
#      text_index                                     labels
# 29           29                    [O, O, O, B-ADJ, I-ADJ]  \
# 54           54                    [B-BRAND, B-ADJ, I-ADJ]
# 193         193                         [B-BRAND, I-BRAND]
# 194         194                           [O, O, B-ADJ, O]
# 197         197                         [B-BRAND, I-BRAND]
# 268         268                   [O, O, B-BRAND, I-BRAND]
# 277         278                               [B-BRAND, O]
# 306         307                            [B-BRAND, O, O]
# 341         342                             [B-ADJ, I-ADJ]
# 364         365                                    [B-ADJ]
# 381         383                             [B-ADJ, B-ADJ]
# 441         443                      [B-BRAND, I-BRAND, O]
# 488         492  [B-BRAND, I-BRAND, I-BRAND, B-ADJ, B-ADJ]
# 540         544                    [B-BRAND, B-QTY, I-QTY]
# 541         545                            [B-BRAND, O, O]
# 565         570                    [B-BRAND, B-ADJ, B-ADJ]
# 566         571                    [B-BRAND, B-ADJ, I-ADJ]
# 567         572                           [B-BRAND, B-ADJ]
# 581         586                                  [O, O, O]
# 591         596                        [O, O, O, B-ADJ, O]
# 630         635                          [O, B-ADJ, B-QTY]
# 651         656                           [B-BRAND, B-ADJ]
# 677         682           [B-BRAND, I-BRAND, B-QTY, I-QTY]
# 688         693                        [B-ADJ, O, O, O, O]
# 804         809                               [O, B-BRAND]
# 818         823                             [B-ADJ, I-ADJ]
# 882         887                               [B-BRAND, O]
# 907         912                 [B-BRAND, O, B-QTY, I-QTY]
# 910         915                                    [B-ADJ]
#
#                        text                  text_tokenized  match
# 29   3002-Kyoto Choco Mochi  [3002, -, Kyoto, Choco, Mochi]   True  \
# 54           AMBUSH DBL CHS              [AMBUSH, DBL, CHS]   True
# 193          CIRENG PANDAWA               [CIRENG, PANDAWA]   True
# 194             CK.MANTAP A              [CK, ., MANTAP, A]   True
# 197               COCA COLA                    [COCA, COLA]   True
# 268           DN. LONG JOHN             [DN, ., LONG, JOHN]   True
# 277             Dendeng PDS                  [Dendeng, PDS]   True
# 306         FIXALL HK 26521             [FIXALL, HK, 26521]   True
# 341              GULAI OTAK                   [GULAI, OTAK]   True
# 364                Hokkaido                      [Hokkaido]   True
# 381              ICED White                   [ICED, White]   True
# 441           KP BRANDING L               [KP, BRANDING, L]   True
# 488         M/POKO STD XXL5         [M, /, POKO, STD, XXL5]   True
# 540           NESTLE 330 ML               [NESTLE, 330, ML]   True
# 541           NESTLE 600 M1               [NESTLE, 600, M1]   True
# 565        Nerds Strw Grape            [Nerds, Strw, Grape]   True
# 566        Nerds Trop Punch            [Nerds, Trop, Punch]   True
# 567        Nerds Watermelon             [Nerds, Watermelon]   True
# 581        ORIGINAL NO SALT            [ORIGINAL, NO, SALT]   True
# 591        P/P AMERICAN FAV        [P, /, P, AMERICAN, FAV]   True
# 630       PR ORIGINAL 150gr           [PR, ORIGINAL, 150gr]   True
# 651         Pocky Chocolate              [Pocky, Chocolate]   True
# 677      REGAL MARIE 125 GR         [REGAL, MARIE, 125, GR]   True
# 688        ROASTED MT ( R )          [ROASTED, MT, (, R, )]   True
# 804      SpcPrice Caudburry           [SpcPrice, Caudburry]   True
# 818               TAKE AWAY                    [TAKE, AWAY]   True
# 882            VALINO DONNA                 [VALINO, DONNA]   True
# 907        YAKULT ISI 5 PCS           [YAKULT, ISI, 5, PCS]   True
# 910                  YELLOW                        [YELLOW]   True
#
#            adj_tags product_tags product_name          adj
# 29   [Choco, Mochi]           []               Choco Mochi
# 54       [DBL, CHS]           []                   DBL CHS
# 193              []           []
# 194        [MANTAP]           []                    MANTAP
# 197              []           []
# 268              []           []
# 277              []           []
# 306              []           []
# 341   [GULAI, OTAK]           []                GULAI OTAK
# 364      [Hokkaido]           []                  Hokkaido
# 381   [ICED, White]           []                ICED White
# 441              []           []
# 488     [STD, XXL5]           []                  STD XXL5
# 540              []           []
# 541              []           []
# 565   [Strw, Grape]           []                Strw Grape
# 566   [Trop, Punch]           []                Trop Punch
# 567    [Watermelon]           []                Watermelon
# 581              []           []
# 591      [AMERICAN]           []                  AMERICAN
# 630      [ORIGINAL]           []                  ORIGINAL
# 651     [Chocolate]           []                 Chocolate
# 677              []           []
# 688       [ROASTED]           []                   ROASTED
# 804              []           []
# 818    [TAKE, AWAY]           []                 TAKE AWAY
# 882              []           []
# 907              []           []
# 910        [YELLOW]           []                    YELLOW

# %%
data = data[data.product_name!=''].reset_index(drop=True)
data = data.groupby('product_name')[['labels', 'text']].first().reset_index()
data.shape
# Out:
# (792, 3)

# %% [markdown]
# ## Convert to embedding

# %% [markdown]
# ### TF-IDF

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
vectorizer = TfidfVectorizer(analyzer='word')
vectors = vectorizer.fit_transform(data.product_name.tolist())
feature_names = vectorizer.get_feature_names_out()
dense = vectors.todense()
denselist = dense.tolist()
df = pd.DataFrame(denselist, columns=feature_names)

# %%
df['product_name'] = data.product_name.tolist()

# %%
df.product_name.nunique()
# Out:
# 792

# %%
from sklearn.metrics.pairwise import cosine_similarity
import scipy

# %%
sparse_test = scipy.sparse.csr_matrix(df[feature_names.tolist()].values)

# %%
cosine_sim = pd.DataFrame(cosine_similarity(sparse_test))
cosine_sim.index = data.text.tolist()
cosine_sim.columns = data.text.tolist()

# %%
cosine_sim
# Out:
#                              Oriental "Ketjap" Pork Rice  Large *Plastik Kcl
# Oriental "Ketjap" Pork Rice                     1.000000                 0.0  \
# Large *Plastik Kcl                              0.000000                 1.0
# 500 days of summer (P)                          0.000000                 0.0
# A.MINERAL GELAS                                 0.000000                 0.0
# A.MINERAL BOTOL                                 0.000000                 0.0
# ...                                                  ...                 ...
# phad thai                                       0.000000                 0.0
# steamed rice                                    0.308012                 0.0
# sun kissed (P)                                  0.000000                 0.0
# green tea                                       0.000000                 0.0
# chapsal twister donnut                          0.000000                 0.0
#
#                              500 days of summer (P)  A.MINERAL GELAS
# Oriental "Ketjap" Pork Rice                     0.0         0.000000  \
# Large *Plastik Kcl                              0.0         0.000000
# 500 days of summer (P)                          1.0         0.000000
# A.MINERAL GELAS                                 0.0         1.000000
# A.MINERAL BOTOL                                 0.0         0.707107
# ...                                             ...              ...
# phad thai                                       0.0         0.000000
# steamed rice                                    0.0         0.000000
# sun kissed (P)                                  0.0         0.000000
# green tea                                       0.0         0.000000
# chapsal twister donnut                          0.0         0.000000
#
#                              A.MINERAL BOTOL  ABURA UDON (ORIGINAL)
# Oriental "Ketjap" Pork Rice         0.000000                    0.0  \
# Large *Plastik Kcl                  0.000000                    0.0
# 500 days of summer (P)              0.000000                    0.0
# A.MINERAL GELAS                     0.707107                    0.0
# A.MINERAL BOTOL                     1.000000                    0.0
# ...                                      ...                    ...
# phad thai                           0.000000                    0.0
# steamed rice                        0.000000                    0.0
# sun kissed (P)                      0.000000                    0.0
# green tea                           0.000000                    0.0
# chapsal twister donnut              0.000000                    0.0
#
#                              ACCESORIES(SUN BABES PENUTUP MATA)  AIR MINERAL
# Oriental "Ketjap" Pork Rice                                 0.0     0.000000  \
# Large *Plastik Kcl                                          0.0     0.000000
# 500 days of summer (P)                                      0.0     0.000000
# A.MINERAL GELAS                                             0.0     0.634352
# A.MINERAL BOTOL                                             0.0     0.448555
# ...                                                         ...          ...
# phad thai                                                   0.0     0.000000
# steamed rice                                                0.0     0.000000
# sun kissed (P)                                              0.0     0.000000
# green tea                                                   0.0     0.000000
# chapsal twister donnut                                      0.0     0.000000
#
#                              ALMOND CHOCO CREAMCHEESE
# Oriental "Ketjap" Pork Rice                       0.0  \
# Large *Plastik Kcl                                0.0
# 500 days of summer (P)                            0.0
# A.MINERAL GELAS                                   0.0
# A.MINERAL BOTOL                                   0.0
# ...                                               ...
# phad thai                                         0.0
# steamed rice                                      0.0
# sun kissed (P)                                    0.0
# green tea                                         0.0
# chapsal twister donnut                            0.0
#
#                              ALMOND CHOCO CREAM CHEESE  ...
# Oriental "Ketjap" Pork Rice                        0.0  ...  \
# Large *Plastik Kcl                                 0.0  ...
# 500 days of summer (P)                             0.0  ...
# A.MINERAL GELAS                                    0.0  ...
# A.MINERAL BOTOL                                    0.0  ...
# ...                                                ...  ...
# phad thai                                          0.0  ...
# steamed rice                                       0.0  ...
# sun kissed (P)                                     0.0  ...
# green tea                                          0.0  ...
# chapsal twister donnut                             0.0  ...
#
#                              garlic pepper beef  caisim special
# Oriental "Ketjap" Pork Rice                 0.0             0.0  \
# Large *Plastik Kcl                          0.0             0.0
# 500 days of summer (P)                      0.0             0.0
# A.MINERAL GELAS                             0.0             0.0
# A.MINERAL BOTOL                             0.0             0.0
# ...                                         ...             ...
# phad thai                                   0.0             0.0
# steamed rice                                0.0             0.0
# sun kissed (P)                              0.0             0.0
# green tea                                   0.0             0.0
# chapsal twister donnut                      0.0             0.0
#
#                              cashew nuts chkn  red curry beef
# Oriental "Ketjap" Pork Rice               0.0             0.0  \
# Large *Plastik Kcl                        0.0             0.0
# 500 days of summer (P)                    0.0             0.0
# A.MINERAL GELAS                           0.0             0.0
# A.MINERAL BOTOL                           0.0             0.0
# ...                                       ...             ...
# phad thai                                 0.0             0.0
# steamed rice                              0.0             0.0
# sun kissed (P)                            0.0             0.0
# green tea                                 0.0             0.0
# chapsal twister donnut                    0.0             0.0
#
#                              Fre ice grentea  phad thai  steamed rice
# Oriental "Ketjap" Pork Rice              0.0        0.0      0.308012  \
# Large *Plastik Kcl                       0.0        0.0      0.000000
# 500 days of summer (P)                   0.0        0.0      0.000000
# A.MINERAL GELAS                          0.0        0.0      0.000000
# A.MINERAL BOTOL                          0.0        0.0      0.000000
# ...                                      ...        ...           ...
# phad thai                                0.0        1.0      0.000000
# steamed rice                             0.0        0.0      1.000000
# sun kissed (P)                           0.0        0.0      0.000000
# green tea                                0.0        0.0      0.000000
# chapsal twister donnut                   0.0        0.0      0.000000
#
#                              sun kissed (P)  green tea  chapsal twister donnut
# Oriental "Ketjap" Pork Rice             0.0        0.0                     0.0
# Large *Plastik Kcl                      0.0        0.0                     0.0
# 500 days of summer (P)                  0.0        0.0                     0.0
# A.MINERAL GELAS                         0.0        0.0                     0.0
# A.MINERAL BOTOL                         0.0        0.0                     0.0
# ...                                     ...        ...                     ...
# phad thai                               0.0        0.0                     0.0
# steamed rice                            0.0        0.0                     0.0
# sun kissed (P)                          1.0        0.0                     0.0
# green tea                               0.0        1.0                     0.0
# chapsal twister donnut                  0.0        0.0                     1.0
#
# [792 rows x 792 columns]

# %%
cosine_sim.sort_values(by='Ice Lemon Tea', ascending=False).head(50)
# Out:
#                              Oriental "Ketjap" Pork Rice  Large *Plastik Kcl
# Ice Lemon Tea                                        0.0            0.000000  \
# ICED LEMON TEA                                       0.0            0.000000
# Lemon iced tea                                       0.0            0.000000
# Lemon                                                0.0            0.000000
# green tea                                            0.0            0.000000
# Hot Tea                                              0.0            0.000000
# CHINESE TEA KWAN'IM                                  0.0            0.000000
# JERUK LEMON IMP                                      0.0            0.000000
# Tebu Lemon                                           0.0            0.000000
# S-Fresh Lemon Lime                                   0.0            0.000000
# EARL GREY MILK TEA                                   0.0            0.000000
# Lychee Ice Tea                                       0.0            0.000000
# ES CHOCO GREEN TEA                                   0.0            0.000000
# DumDum Thai Iced Green Tea                           0.0            0.000000
# ICED TEA                                             0.0            0.000000
# REGULAR JASMINE TEA                                  0.0            0.000000
# OREO GREEN TEA SPREAD                                0.0            0.000000
# Free Ice Tea                                         0.0            0.000000
# Chinese Tea                                          0.0            0.000000
# FUSION TEA LYCHE                                     0.0            0.000000
# Sweet Tea                                            0.0            0.000000
# XXI Java Tea (M)                                     0.0            0.000000
# S-Hazelnut Milk Tea                                  0.0            0.000000
# GREEN TEA LYCHEE                                     0.0            0.000000
# GREEN TEA LATTE (L)                                  0.0            0.000000
# S-Caramel Milk Tea                                   0.0            0.000000
# PEARL CHOCO TEA                                      0.0            0.000000
# S-Bubble Milk Tea                                    0.0            0.000000
# Chinese Tea-Jasmine                                  0.0            0.000000
# THAI ICED TEA                                        0.0            0.000000
# ICED HIBISCUS LYCHEE TEA                             0.0            0.000000
# JAPANEESE GR TEA HOT                                 0.0            0.000000
# LIPTON PITCHER                                       0.0            0.000000
# PLASTIK BAG;: 000 PC                                 0.0            0.707107
# PHO TAI CHIN(R)                                      0.0            0.000000
# PHO BO TAI                                           0.0            0.000000
# PHOTAI CHIN                                          0.0            0.000000
# PLASTIC BAG                                          0.0            0.000000
# PEPPER AUS                                           0.0            0.000000
# PLASTIK 25                                           0.0            1.000000
# #PKTPOLSBTSPON2S                                     0.0            0.000000
# PILLOW DURIA                                         0.0            0.000000
# PIRATES TREASURE                                     0.0            0.000000
# PEPPERONI                                            0.0            0.000000
# Oriental "Ketjap" Pork Rice                          1.0            0.000000
# WACOM BAMBOO PEN                                     0.0            0.000000
# PEACH PASTRY                                         0.0            0.000000
# Onde-Onde                                            0.0            0.000000
# Ice Orange                                           0.0            0.000000
# Ori Bento                                            0.0            0.000000
#
#                              500 days of summer (P)  A.MINERAL GELAS
# Ice Lemon Tea                                   0.0              0.0  \
# ICED LEMON TEA                                  0.0              0.0
# Lemon iced tea                                  0.0              0.0
# Lemon                                           0.0              0.0
# green tea                                       0.0              0.0
# Hot Tea                                         0.0              0.0
# CHINESE TEA KWAN'IM                             0.0              0.0
# JERUK LEMON IMP                                 0.0              0.0
# Tebu Lemon                                      0.0              0.0
# S-Fresh Lemon Lime                              0.0              0.0
# EARL GREY MILK TEA                              0.0              0.0
# Lychee Ice Tea                                  0.0              0.0
# ES CHOCO GREEN TEA                              0.0              0.0
# DumDum Thai Iced Green Tea                      0.0              0.0
# ICED TEA                                        0.0              0.0
# REGULAR JASMINE TEA                             0.0              0.0
# OREO GREEN TEA SPREAD                           0.0              0.0
# Free Ice Tea                                    0.0              0.0
# Chinese Tea                                     0.0              0.0
# FUSION TEA LYCHE                                0.0              0.0
# Sweet Tea                                       0.0              0.0
# XXI Java Tea (M)                                0.0              0.0
# S-Hazelnut Milk Tea                             0.0              0.0
# GREEN TEA LYCHEE                                0.0              0.0
# GREEN TEA LATTE (L)                             0.0              0.0
# S-Caramel Milk Tea                              0.0              0.0
# PEARL CHOCO TEA                                 0.0              0.0
# S-Bubble Milk Tea                               0.0              0.0
# Chinese Tea-Jasmine                             0.0              0.0
# THAI ICED TEA                                   0.0              0.0
# ICED HIBISCUS LYCHEE TEA                        0.0              0.0
# JAPANEESE GR TEA HOT                            0.0              0.0
# LIPTON PITCHER                                  0.0              0.0
# PLASTIK BAG;: 000 PC                            0.0              0.0
# PHO TAI CHIN(R)                                 0.0              0.0
# PHO BO TAI                                      0.0              0.0
# PHOTAI CHIN                                     0.0              0.0
# PLASTIC BAG                                     0.0              0.0
# PEPPER AUS                                      0.0              0.0
# PLASTIK 25                                      0.0              0.0
# #PKTPOLSBTSPON2S                                0.0              0.0
# PILLOW DURIA                                    0.0              0.0
# PIRATES TREASURE                                0.0              0.0
# PEPPERONI                                       0.0              0.0
# Oriental "Ketjap" Pork Rice                     0.0              0.0
# WACOM BAMBOO PEN                                0.0              0.0
# PEACH PASTRY                                    0.0              0.0
# Onde-Onde                                       0.0              0.0
# Ice Orange                                      0.0              0.0
# Ori Bento                                       0.0              0.0
#
#                              A.MINERAL BOTOL  ABURA UDON (ORIGINAL)
# Ice Lemon Tea                            0.0                    0.0  \
# ICED LEMON TEA                           0.0                    0.0
# Lemon iced tea                           0.0                    0.0
# Lemon                                    0.0                    0.0
# green tea                                0.0                    0.0
# Hot Tea                                  0.0                    0.0
# CHINESE TEA KWAN'IM                      0.0                    0.0
# PEACH PASTRY                                 0.000000
# Onde-Onde                                    0.000000
# Ice Orange                                   0.000000
# Ori Bento                                    0.000000
#
#                              ALMOND CHOCO CREAM CHEESE  ...
# Ice Lemon Tea                                      0.0  ...  \
# ICED LEMON TEA                                     0.0  ...
# Lemon iced tea                                     0.0  ...
# Lemon                                              0.0  ...
# green tea                                          0.0  ...
# Hot Tea                                            0.0  ...
# CHINESE TEA KWAN'IM                                0.0  ...
# JERUK LEMON IMP                                    0.0  ...
# Tebu Lemon                                         0.0  ...
# S-Fresh Lemon Lime                                 0.0  ...
# EARL GREY MILK TEA                                 0.0  ...
# Lychee Ice Tea                                     0.0  ...
# ES CHOCO GREEN TEA                                 0.0  ...
# DumDum Thai Iced Green Tea                         0.0  ...
# ICED TEA                                           0.0  ...
# REGULAR JASMINE TEA                                0.0  ...
# OREO GREEN TEA SPREAD                              0.0  ...
# Free Ice Tea                                       0.0  ...
# Chinese Tea                                        0.0  ...
# FUSION TEA LYCHE                                   0.0  ...
# Sweet Tea                                          0.0  ...
# XXI Java Tea (M)                                   0.0  ...
# S-Hazelnut Milk Tea                                0.0  ...
# GREEN TEA LYCHEE                                   0.0  ...
# GREEN TEA LATTE (L)                                0.0  ...
# S-Caramel Milk Tea                                 0.0  ...
# PEARL CHOCO TEA                                    0.0  ...
# S-Bubble Milk Tea                                  0.0  ...
# Chinese Tea-Jasmine                                0.0  ...
# THAI ICED TEA                                      0.0  ...
# ICED HIBISCUS LYCHEE TEA                           0.0  ...
# JAPANEESE GR TEA HOT                               0.0  ...
# LIPTON PITCHER                                     0.0  ...
# PLASTIK BAG;: 000 PC                               0.0  ...
# PHO TAI CHIN(R)                                    0.0  ...
# PHO BO TAI                                         0.0  ...
# PHOTAI CHIN                                        0.0  ...
# PLASTIC BAG                                        0.0  ...
# PEPPER AUS                                         0.0  ...
# PLASTIK 25                                         0.0  ...
# #PKTPOLSBTSPON2S                                   0.0  ...
# PILLOW DURIA                                       0.0  ...
# PIRATES TREASURE                                   0.0  ...
# PEPPERONI                                          0.0  ...
# Oriental "Ketjap" Pork Rice                        0.0  ...
# WACOM BAMBOO PEN                                   0.0  ...
# PEACH PASTRY                                       0.0  ...
# Onde-Onde                                          0.0  ...
# Ice Orange                                         0.0  ...
# Ori Bento                                          0.0  ...
#
#                              garlic pepper beef  caisim special
# Ice Lemon Tea                               0.0             0.0  \
# ICED LEMON TEA                              0.0             0.0
# Lemon iced tea                              0.0             0.0
# Lemon                                       0.0             0.0
# green tea                                   0.0             0.0
# Hot Tea                                     0.0             0.0
# CHINESE TEA KWAN'IM                         0.0             0.0
# JERUK LEMON IMP                             0.0             0.0
# Tebu Lemon                                  0.0             0.0
# S-Fresh Lemon Lime                          0.0             0.0
# EARL GREY MILK TEA                          0.0             0.0
# Lychee Ice Tea                              0.0             0.0
# ES CHOCO GREEN TEA                          0.0             0.0
# DumDum Thai Iced Green Tea                  0.0             0.0
# ICED TEA                                    0.0             0.0
# REGULAR JASMINE TEA                         0.0             0.0
# OREO GREEN TEA SPREAD                       0.0             0.0
# Ori Bento                               0.0   0.000000                     0.0
#
# [50 rows x 792 columns]

# %% [markdown]
# ### Bert embeddings

# %% [markdown]
# Making use of pretrained Bert to do word embeddings

# %%
data
# Out:
#              product_name                                           labels
# 0    " Ketjap " Pork Rice  [B-ADJ, B-PROD, I-PROD, I-PROD, I-PROD, I-PROD]  \
# 1               * Plastik                       [B-ADJ, B-PROD, I-PROD, O]
# 2      500 days of summer        [B-PROD, I-PROD, I-PROD, I-PROD, O, O, O]
# 3             A . MINERAL                  [B-PROD, I-PROD, I-PROD, B-ADJ]
# 4       A . MINERAL BOTOL                 [B-PROD, I-PROD, I-PROD, I-PROD]
# ..                    ...                                              ...
# 787             phad thai                                 [B-PROD, I-PROD]
# 788          steamed rice                                 [B-PROD, I-PROD]
# 789            sun kissed                        [B-PROD, I-PROD, O, O, O]
# 790                   tea                                  [B-ADJ, B-PROD]
# 791        twister donnut                              [O, B-PROD, I-PROD]
#
#                             text
# 0    Oriental "Ketjap" Pork Rice
# 1             Large *Plastik Kcl
# 2         500 days of summer (P)
# 3                A.MINERAL GELAS
# 4                A.MINERAL BOTOL
# ..                           ...
# 787                    phad thai
# 788                 steamed rice
# 789               sun kissed (P)
# 790                    green tea
# 791       chapsal twister donnut
#
# [792 rows x 3 columns]

# %%
texts = data.product_name.unique().tolist()
tokenized_text = list(map(tokenizer.tokenize, texts))
indexed_tokens = list(map(tokenizer.convert_tokens_to_ids, tokenized_text))

# %%
segments_ids = list(map(lambda x: [1] * len(x), indexed_tokens))

# %%
tokens_tensor = [torch.tensor([x]) for x in indexed_tokens]
segments_tensors = [torch.tensor([x]) for x in segments_ids]

# %%
BertModel
# Out:
# __main__.BertModel

# %%
# Load pre-trained model (weights)
emb_model = BertModel.from_pretrained('bert-base-uncased',
                                  output_hidden_states = True, # Whether the model returns all hidden-states.
                                  )

# Put the model in "evaluation" mode, meaning feed-forward operation.
emb_model.eval()
# Out:
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertModel: ['cls.predictions.bias', 'cls.predictions.transform.LayerNorm.bias', 'cls.seq_relationship.bias', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.dense.weight', 'cls.seq_relationship.weight', 'cls.predictions.decoder.weight', 'cls.predictions.transform.LayerNorm.weight']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# BertModel(
#   (embeddings): BertEmbeddings(
#     (word_embeddings): Embedding(30522, 768, padding_idx=0)
#     (position_embeddings): Embedding(512, 768)
#     (token_type_embeddings): Embedding(2, 768)
#     (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (encoder): BertEncoder(
#     (layer): ModuleList(
#       (0-11): 12 x BertLayer(
#         (attention): BertAttention(
#           (self): BertSelfAttention(
#             (query): Linear(in_features=768, out_features=768, bias=True)
#             (key): Linear(in_features=768, out_features=768, bias=True)
#             (value): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (output): BertSelfOutput(
#             (dense): Linear(in_features=768, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (intermediate): BertIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, bias=True)
#           (intermediate_act_fn): GELUActivation()
#         )
#         (output): BertOutput(
#           (dense): Linear(in_features=3072, out_features=768, bias=True)
#           (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#     )
#   )
#   (pooler): BertPooler(
#     (dense): Linear(in_features=768, out_features=768, bias=True)
#     (activation): Tanh()
#   )
# )

# %%
outputs = []
for i in range(len(tokens_tensor)):
    with torch.no_grad():
        outputs.append(emb_model(tokens_tensor[i], segments_tensors[i]))

# %%
token_vecs = list(map(lambda x: x[2][-2][0], outputs))

# %%
sentence_embeddings = list(map(lambda x: torch.mean(x, dim=0), token_vecs))

# %%
from sklearn.metrics.pairwise import cosine_similarity
import scipy

# %%
sparse_bert = scipy.sparse.csr_matrix(torch.stack(sentence_embeddings))

# %%
cosine_sim = pd.DataFrame(cosine_similarity(sparse_bert))
cosine_sim.columns=data.text.unique().tolist()
cosine_sim.index = data.text.unique().tolist()

# %%
cosine_sim[['Ice Lemon Tea']].sort_values(by='Ice Lemon Tea', ascending=False).head(50)
# Out:
#                                 Ice Lemon Tea
# Ice Lemon Tea                        1.000001
# ICED LEMON TEA                       1.000001
# Lemon iced tea                       1.000001
# S-Fresh Lemon Lime                   0.959027
# Sweet Tea                            0.923163
# CHOCOLATE TWIST                      0.877407
# Chocolate Twist                      0.877407
# REGULAR JASMINE TEA                  0.873812
# REAL CHOCOLATE ROLL                  0.871326
# AQUA AIR MINERAL 600                 0.870291
# 4002-Chocolate Orange Peel           0.869251
# red curry beef                       0.866812
# Chicken Vege Rice Bowl               0.866150
# ORANGE JUICE                         0.864994
# CHICKEN KATSU CURRY RICE             0.864682
# Kimchi P                             0.863706
# MARMER CAKE PTG                      0.861241
# Lemon                                0.857689
# Kwan Yin Cup                         0.856701
# REAL HONEY PANCAKE BREAD             0.856532
# APPLE CINNAMON PASTRY                0.854397
# KING DEAL CHEESE BURGER R            0.850751
# S-Hazelnut Milk Tea                  0.848510
# Crab Stick                           0.848272
# WHITE CHOCO BANANA SPREAD            0.848128
# Chicken Cesar Salad                  0.847305
# CHICKEN KATSU CURRY UDON             0.846899
# Home Made Lemonade                   0.845401
# KOREAN LEMONADE                      0.845401
# REAL CHEESE INSIDE BREAD             0.842767
# TOAST BREAD                          0.839133
# Chinese Tea-Jasmine                  0.838626
# MINUMAN KEMASAN/REFILL               0.830377
# 6001-Plastic Bag Small               0.829604
# PLASTIC BAG                          0.829604
# Snowman Cake Chocolate               0.829051
# TAIL STOMACH (S)                     0.828674
# Astor Stick Cokelat 40gr             0.827133
# PIRATES TREASURE                     0.825065
# SURIMI - SATSUMA AGE VEGETABLE       0.824725
# Choco Melt                           0.823700
# Chinese Tea                          0.822587
# Chicken Maryland                     0.821834
# Gojek Chicken Chilli Sauce H         0.820417
# APPLE PIE                            0.820219
# S-Bubble Milk Tea                    0.820057
# TRAD KY TOAST CARTE                  0.819473
# Pink Panther (P)                     0.818487
# 1023-Chocochip & Walnut              0.818190
# DORI SAMBAL MATAH 1+1                0.818079

# %% [markdown]
# ## Fuzzy Matching

# %% [markdown]
# ### Levenshtein Distance

# %%
import Levenshtein as lev

# %%
texts = data.text.tolist()
product_names = data.product_name.tolist()

# %%
text_mat = {}
for i in texts:
    curr_row = []
    for j in texts:
        curr_row.append(lev.distance(i, j))
    text_mat[i] = curr_row

# %%
text_lev = pd.DataFrame(text_mat)
text_lev.index = texts

# %%
text_lev.sort_values(by='Ice Lemon Tea').head(20)
# Out:
#                   Large *Plastik Kcl  500 days of summer (P)  A.MINERAL GELAS
# A.MINERAL GELAS                   18                      21                0  \
# A.MINERAL BOTOL                   18                      21                5
# * MINERAL WATER                   18                      20                7
# DONAT GULA                        17                      21                9
# JASMINE MT ( L )                  17                      18                9
# AIR MINERAL                       17                      21                9
# ICED TEA                          17                      21               10
# CUMI BANGKA                       16                      21               10
# MIKA SEDANG                       17                      21               10
# MIKA KECIL                        17                      21               10
# CHINESE TE                        17                      21               10
# AMANDEL BROOD                     18                      21               10
# GONG GIBAB                        17                      21               11
# TEH BTL ES                        16                      20               11
# LALAP SEGAR                       16                      21               11
# ICED GT                           17                      21               11
# REDBEAN BREAD                     18                      21               11
# RB. RED BEAN                      17                      20               11
# SAMBAL TRI BELAH                  18                      21               11
# MANUKA HONEY                      18                      21               11
#
#                   A.MINERAL BOTOL  ACCESORIES(SUN BABES PENUTUP MATA)
# A.MINERAL GELAS                 5                                  27  \
# A.MINERAL BOTOL                 0                                  28
# * MINERAL WATER                 6                                  28
# DONAT GULA                     12                                  28
# JASMINE MT ( L )               10                                  26
# AIR MINERAL                     9                                  29
# ICED TEA                       11                                  29
# JASMINE MT ( L )                15              15               15
# AIR MINERAL                     15              13               14
# ICED TEA                        15              13               14
# CUMI BANGKA                     15              14               14
# MIKA SEDANG                     15              14               14
# MIKA KECIL                      15              14               14
# CHINESE TE                      15              13               14
# AMANDEL BROOD                   16              14               14
# GONG GIBAB                      15              14               14
# TEH BTL ES                      14              12               13
# LALAP SEGAR                     15              14               14
# ICED GT                         15              13               14
# REDBEAN BREAD                   16              14               14
# RB. RED BEAN                    14              12               13
# SAMBAL TRI BELAH                15              15               16
# MANUKA HONEY                    15              14               14
#
#                   phad thai  steamed rice  sun kissed (P)  green tea
# A.MINERAL GELAS          14            14              15         14  \
# A.MINERAL BOTOL          14            14              15         14
# * MINERAL WATER          14            14              15         14
# DONAT GULA                9            11              14          9
# JASMINE MT ( L )         15            15              13         15
# AIR MINERAL              11            12              13         11
# ICED TEA                  8            11              13          8
# CUMI BANGKA              10            12              14         11
# MIKA SEDANG              10            12              14         11
# MIKA KECIL                9            12              14         10
# CHINESE TE               10            11              13         10
# AMANDEL BROOD            12            12              14         12
# GONG GIBAB                9            12              14         10
# TEH BTL ES               10            11              12         10
# LALAP SEGAR              10            12              14         10
# ICED GT                   8            11              13          8
# REDBEAN BREAD            12            12              14         12
# RB. RED BEAN             11            11              13         11
# SAMBAL TRI BELAH         15            15              15         15
# MANUKA HONEY             11            12              14         11
#
#                   chapsal twister donnut
# A.MINERAL GELAS                       21
# A.MINERAL BOTOL                       21
# * MINERAL WATER                       20
# DONAT GULA                            21
# JASMINE MT ( L )                      20
# AIR MINERAL                           21
# ICED TEA                              21
# CUMI BANGKA                           21
# MIKA SEDANG                           21
# MIKA KECIL                            21
# CHINESE TE                            21
# AMANDEL BROOD                         21
# GONG GIBAB                            21
# TEH BTL ES                            20
# LALAP SEGAR                           21
# ICED GT                               21
# REDBEAN BREAD                         21
# RB. RED BEAN                          20
# SAMBAL TRI BELAH                      20
# MANUKA HONEY                          21
#
# [20 rows x 613 columns]

# %% [markdown]
# ### Jaro Winkler

# %%
import jaro

# %%
texts = data.text.tolist()
product_names = data.product_name.tolist()

# %%
text_mat = {}
for i in texts:
    curr_row = []
    for j in texts:
        curr_row.append(jaro.jaro_winkler_metric(i, j))
    text_mat[i] = curr_row

# %%
text_lev = pd.DataFrame(text_mat)
text_lev.index = texts

# %%
text_lev.sort_values(by='Ice Lemon Tea', ascending=False).head(20)
# Out:
#                       Large *Plastik Kcl  500 days of summer (P)
# green tea                       0.555556                0.378788  \
# Free Ice Tea                    0.498148                0.421717
# Sweet Tea                       0.472222                0.378788
# Pepenero Pastel                 0.534259                0.386869
# Ice Lemon Tea                   0.420798                0.466977
# Fre ice grentea                 0.534259                0.453535
# Organic Green Sa                0.523148                0.379924
# Lychee Ice Tea                  0.531746                0.394805
# Arem Arem                       0.500000                0.378788
# Mineral Water                   0.547212                0.413170
# garlic pepper beef              0.504630                0.368687
# Cheese Tart                     0.515152                0.431818
# Cheese Croquette                0.463426                0.382576
# Cafe Latte                      0.533333                0.443939
# steamed rice                    0.500000                0.490981
# Kroket                          0.555556                0.404040
# Fre ice grentea        0.451852      0.588095        0.434127   0.652910
# Organic Green Sa       0.395833      0.530754        0.489881   0.643188
# Lychee Ice Tea         0.515873      0.591270        0.365079   0.637566
# Arem Arem              0.407407      0.590741        0.288360   0.629630
# Mineral Water          0.500712      0.533761        0.364469   0.629223
# garlic pepper beef     0.472222      0.578704        0.419312   0.626984
# Cheese Tart            0.535354      0.570707        0.384560   0.626263
# Cheese Croquette       0.449074      0.513889        0.356151   0.625000
# Cafe Latte             0.531481      0.411111        0.280952   0.618519
# steamed rice           0.524074      1.000000        0.457937   0.611111
# Kroket                 0.425926      0.333333        0.492063   0.611111
# Cheezemania            0.535354      0.557071        0.384560   0.603367
# Pecel Komplit + Nasi   0.381481      0.544444        0.411905   0.601852
# Tempe Goreng           0.462963      0.666667        0.269841   0.592593
# Fried Siomay           0.509259      0.477778        0.373016   0.592593
#
#                       chapsal twister donnut
# green tea                           0.458754
# Free Ice Tea                        0.414646
# Sweet Tea                           0.460943
# Pepenero Pastel                     0.521549
# Ice Lemon Tea                       0.476024
# Fre ice grentea                     0.521549
# Organic Green Sa                    0.546086
# Lychee Ice Tea                      0.511544
# Arem Arem                           0.378788
# Mineral Water                       0.493007
# garlic pepper beef                  0.562290
# Cheese Tart                         0.556277
# Cheese Croquette                    0.509049
# Cafe Latte                          0.568687
# steamed rice                        0.571549
# Kroket                              0.308081
# Cheezemania                         0.494949
# Pecel Komplit + Nasi                0.551515
# Tempe Goreng                        0.479798
# Fried Siomay                        0.414646
#
# [20 rows x 613 columns]

# %% [markdown]
# ## Create product groups

# %%
data['product_group'] = data['product_name'].apply(lambda x: 'lemon' if 'lemon' in x.lower() else 'ayam' if 'ayam' in x.lower() else 'cheese' if 'cheese' in x.lower() else None)

# %%
data.product_group.value_counts()
# Out:
# product_group
# ayam      21
# cheese    20
# lemon     10
# Name: count, dtype: int64

# %%
data[data.product_group=='lemon']
# Out:
#         product_name                                 labels
# 347      JERUK LEMON                    [B-PROD, I-PROD, O]  \
# 403        LEMON TEA                [B-ADJ, B-PROD, I-PROD]
# 404         LEMONADE                        [B-ADJ, B-PROD]
# 416            Lemon                               [B-PROD]
# 417       Lemon Lime  [B-ADJ, I-ADJ, I-ADJ, B-PROD, I-PROD]
# 418        Lemon Tea                [B-ADJ, B-PROD, I-PROD]
# 419        Lemon tea                [B-PROD, B-ADJ, B-PROD]
# 420         Lemonade                 [B-ADJ, I-ADJ, B-PROD]
# 421  Lemongrass Aloe                    [O, B-PROD, B-PROD]
# 740       Tebu Lemon                       [B-PROD, I-PROD]
#
#                     text product_group
# 347      JERUK LEMON IMP         lemon
# 403       ICED LEMON TEA         lemon
# 404      KOREAN LEMONADE         lemon
# 416                Lemon         lemon
# 417   S-Fresh Lemon Lime         lemon
# 418        Ice Lemon Tea         lemon
# 419       Lemon iced tea         lemon
# 420   Home Made Lemonade         lemon
# 421  RTD Lemongrass Aloe         lemon
# 740           Tebu Lemon         lemon

# %%
anomalies = ['steamed rice', 'garlic pepper beef', 'Pepenero Pastel']
